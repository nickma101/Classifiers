# %% [markdown]
# # Manual Content Analysis - Data overview
#
# This Jupyter Notebook provides an overview over the articles that were coded for the manual content analysis and the distribution of their labels.

# %% [markdown]
# ## Load packages

# %%
#import relevant packages
import pandas as pd
from pandas import read_excel
import re
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import RandomizedSearchCV, ShuffleSplit, GridSearchCV, train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from pprint import pprint
import spacy
#import German language model
import de_core_news_md
#define nlp pipe
nlp = de_core_news_md.load()

# %% [markdown]
# ## Read data

# %%
#read in the manually coded data
mca = read_excel("mca_data.xlsx")

#read in the article data
#first Dataset A
articles = read_excel("sample.xlsx")
#then Dataset B
articles_online = read_excel("sample_online_new.xlsx")
#then Dataset C
articles2 = read_excel("Dataset C.xlsx")
print(len(articles), len(articles_online), len(articles2))
# Out:
# 250 150 98

# %%
#add the two print dfs together
articles = articles.append(articles2)
len(articles)
# Out:
# 348

# %%
articles
# Out:
#       ID                                     Newspaper        Date  \
# 0   2471                               Rheinische Post  2020-05-02
# 1   6803                              Der Tagesspiegel  2020-05-19
# 2    779                                      Die Welt  2020-04-22
# 3   3110                           Stuttgarter Zeitung  2020-04-30
# 4   3266                           Stuttgarter Zeitung  2020-04-25
# 5    738                                      Die Welt  2020-04-22
# 6   1122                                      Die Welt  2020-05-04
# 7   5298  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-14
# 8   4761  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-08
# 9   1538                               Rheinische Post  2020-04-23
# 10  5045  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-15
# 11   573                              Aachener Zeitung  2020-05-02
# 12  5591  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-02
# 13  5364  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-12
# 14   815                                      Die Welt  2020-04-20
# 15  3401                           Stuttgarter Zeitung  2020-05-07
# 16  2192                               Rheinische Post  2020-05-13
# 17  5156  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-16
# 18  4437  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-21
# 19  5907  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-05
# 20  4917  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-18
# 21  2045                               Rheinische Post  2020-05-15
# 22  5690  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-08
# 23  6878                              Der Tagesspiegel  2020-05-15
# 24  1842                               Rheinische Post  2020-04-22
# 25  4863  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-11
# 26  1607                               Rheinische Post  2020-04-24
# 27  3337                           Stuttgarter Zeitung  2020-04-27
# 28  5843  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-06
# 29  4338  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-28
# ..   ...                                           ...         ...
# 68  4513  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-29
# 69  2691                               Rheinische Post  2020-05-07
# 70  3082                           Stuttgarter Zeitung  2020-04-29
# 71  5553  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-05
# 72  6039  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-04
# 73  6237  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-02
# 74  2162                               Rheinische Post  2020-05-14
# 75   263                              Aachener Zeitung  2020-05-07
# 76  2976                               Rheinische Post  2020-05-14
# 77  6992                              Der Tagesspiegel  2020-05-07
# 78  4327  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-29
# 79  5199  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-14
# 80  4105  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-27
# 81  3193                           Stuttgarter Zeitung  2020-04-29
# 82   276                              Aachener Zeitung  2020-05-19
# 83  5517  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-11
# 84  6225  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-02
# 85  1918                               Rheinische Post  2020-05-04
# 86  3236                           Stuttgarter Zeitung  2020-04-30
# 87  3677                           Stuttgarter Zeitung  2020-05-15
# 88  4010  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020
# 26  Erkrath (hup) Die CDU setzt sich für einen bes...
# 27  Das schöne Wetter lockt in diesen Tagen viele ...
# 28  New York - Wenn man nach New York City blickt,...
# 29  Moosburg - Die ,,aktive Unterstützung von Moos...
# ..                                                ...
# 68  Erding - Die Forsterner Grünen kritisieren in ...
# 69  Berlin (dpa) Urlauber können im Sommer unter U...
# 70  Die Universitäten stehen vor einem sehr schwie...
# 71  Neubiberg - Zum Treffen im Zukunftswald im Lan...
# 72  Altomünster - Die Marktgemeinde wird im Sommer...
# 73  ,,Eigentlich mache ich momentan eine Ausbildun...
# 74  marlen Kess Düsseldorf Seit sieben Wochen sind...
# 75  Von Guido Jansen   Jülich Der Brainergy-Park h...
# 76  Düsseldorf (dpa) In Deutschland gibt es derzei...
# 77  B erlin reiht sich nicht ein in die Riege der ...
# 78  Wien - Die erste Öffnung hat keinen Rückschlag...
# 79  München - Haushaltskonsolidierung, Gesundheits...
# 80  Dachau - Die Fraktion der Überparteilichen Bür...
# 81  Genau beziffern kann Finanzministerin Edith Si...
# 82  Freiburg Ein Wissenschaftlerteam der Universit...
# 83  Unser Kontinent steht inmitten einer Bewährung...
# 84  Landkreis - Wegen der Corona-Krise ist auch im...
# 85  Rheurdt (got) Im Nachhinein ist Robert Peerenb...
# 86  Normalerweise würden Felix Winkler und seine K...
# 87  Der Betriebsausschuss Städtische Gebäude hat z...
# 88  Seit er als verschreckter Schüler einer Kadett...
# 89  Peter Clement Haan/Kreis Mettmann In dieser St...
# 90  Eine entspannte Urlaubsreise sieht sicher ande...
# 91  Berlin Entwicklungsminister Gerd Müller plädie...
# 92  Berlin/München - Knapp 250 Menschen sind in So...
# 93  Berlin - Der Petersberger Klimadialog soll all...
# 94  Frankfurt am Main/Brüssel - Die deutsche Wirts...
# 95  Die Coronakrise sei die schlimmste Pandemie se...
# 96  Dinslaken (aha)Tausende haben in den vergangen...
# 97  Wie sehen in 20, 30, 40 oder 50 Jahren Krieg u...
#
#                           Author
# 0              Plück, Maximilian
# 1                            NaN
# 2                  Tobias Käufer
# 3                            AFP
# 4                            dpa
# 5                    Klaus Boldt
# 6                Jürgen Rüttgers
# 7                            NaN
# 8                  IRIS HILBERTH
# 9           Gaasterland, Hendrik
# 10                  LISA SCHNELL
# 11                           NaN
# 12              WOLFGANG JANISCH
# 13                           WKB
# 14                   Kaja Klapsa
# 15                Frank Herrmann
# 16               Treffer, Bianca
# 17                  ILONA GERDOM
# 18                           AJU
# 19              KATHARINA AURICH
# 20                   SONJA ZEKRI
# 21                           NaN
# 22            VON JENS SCHNEIDER
# 23               Reinhart Bünger
# 24                  Röse, Martin
# 25    VON RAINER RUTZRAINER RUTZ
# 26                           NaN
# 27                           wed
# 28             CHRISTIAN ZASCHKE
# 29                          AXKA
# ..                           ...
# 68                      FLO, TDR
# 69                           NaN
# 70                Norbert Wallet
# 71              VON DANIELA BODE
# 72                          KRAM
# 73         PROTOKOLL: NINA BÜCHS
# 74                   Keß, Marlen
# 75                           NaN
# 76                           NaN
# 77                Sabine Beikler
# 78                            SZ
# 79          VON DOMINIK HUTTERSZ
# 80                            SZ
# 81             Christiane Rebhan
# 82                           NaN
# 83             Von Oliver Hermes
# 84                            SZ
# 85            Gottschlich, Peter
# 86               Barbara Czimmer
# 87               Andreas Pflüger
# 88         VON RUDOLF VON BITTER
# 89                Clement, Peter
# 90                           NaN
# 91                           NaN
# 92  KRISTIANA LUDWIG, ANNA REUSS
# 93                           NaN
# 94                           NaN
# 95                   Dirk Ludigs
# 96                           NaN
# 97               Gerhard Hegmann
#
# [348 rows x 7 columns]

# %% [markdown]
# ## Pre-processing

# %%
#selecting only the relevant columns
mca = mca[["CID", "AID", "NO", "CPA", "BOV", "BOA", "NEU"]]
#drop the firs row, because it contains the column names
mca = mca.drop(mca.index[0])
#reset the index
mca = mca.reset_index()
#inspect the data
mca.head()
# Out:
#    index CID   AID NO CPA BOV BOA NEU
# 0      1  03   490  1   3   2   2   2
# 1      2  03  3414  3   1   1   1   2
# 2      3  03  6996  4   3   2   2   1
# 3      4  03  4894  5   3   2   2   1
# 4      5  03  3110  3   3   2   2   2

# %%
#change the datatypes of the manually coded df
mca = mca[mca["AID"].notna()]
mca["AID"] = mca["AID"].astype(int)
mca["CID"] = mca["CID"].astype(int)
mca["NO"] = mca["NO"].astype(int)
mca["CPA"] = mca["CPA"].astype(int)
mca = mca[mca["BOV"].notna()]
mca["BOV"] = mca["BOV"].astype(int)
mca["BOA"] = mca["BOA"].astype(int)
mca["NEU"] = mca["NEU"].astype(int)

# %%
articles = articles.rename(columns= {"ID":"AID"})
articles.head()
# Out:
#     AID            Newspaper        Date     Length  \
# 0  2471      Rheinische Post  2020-05-02  291 words
# 1  6803     Der Tagesspiegel  2020-05-19  418 words
# 2   779             Die Welt  2020-04-22  595 words
# 3  3110  Stuttgarter Zeitung  2020-04-30  287 words
# 4  3266  Stuttgarter Zeitung  2020-04-25  198 words
#
#                                             Headline  \
# 0                     Die Demontage einer Ministerin
# 1  Microsoft mahnt Berlin ab Der US-Konzern verla...
# 2  Bolsonaro verliert die Nerven; Brasiliens Staa...
# 3                         Anklage im Mordfall Lübcke
# 4  Maskenpflicht auchin Schulen?; Bundesbildungsm...
#
#                                              Article             Author
# 0  Maximilian Plück Armin Laschet brauchte am Don...  Plück, Maximilian
# 1  Gegenwind für die Berliner Beauftragte für Dat...                NaN
# 2  Jair Bolsonaro sieht müde aus, mehrfach hustet...      Tobias Käufer
# 3  Die Bundesanwaltschaft hat Anklage im Fall des...                AFP
# 4  Bundesbildungsministerin Anja Karliczek (CDU) ...                dpa

# %% [markdown]
# ## Merging the dataframes

# %%
#change the AID column dtype for the article df -> necessary for merging
articles["AID"] = articles["AID"].astype(int)
#merge the mca data with the article data
df = mca.merge(articles, how="left", on="AID")
#check for duplicates
duplicates = df[df.duplicated(["AID"])]
#check the length
len(df)
# Out:
# 575

# %%
#rename columns
articles_online = articles_online.rename(columns={"ID":"AID"})
#select only the AID (to merge on) and the text
articles_online = articles_online[["AID", "Article", "Newspaper"]]
#merge the dataframe with the online article data
df = df.merge(articles_online, how="left", on="AID")
#inspect the data
df.head(3)
# Out:
#    index  CID   AID  NO  CPA  BOV  BOA  NEU          Newspaper_x        Date  \
# 0      1    3   490   1    3    2    2    2     Aachener Zeitung  2020-05-15
# 1      2    3  3414   3    1    1    1    2  Stuttgarter Zeitung  2020-05-15
# 2      3    3  6996   4    3    2    2    1     Der Tagesspiegel  2020-05-10
#
#       Length                          Headline  \
# 0   43 words  FDP lädt ein zur Wahlversammlung
# 1  576 words        Wer stopft das Steuerloch?
# 2  801 words     Schulbetrieb und Klassenfahrt
#
#                                            Article_x         Author Article_y  \
# 0  Simmerath Der FDP Ortsverein Simmerath lädt zu...            NaN       NaN
# 1  Angesichts der gigantischen Steuer-ausfälle im...  Thorsten Knuf       NaN
# 2  "Kindeswohlgefährdung begünstigt. Experten bes...            NaN       NaN
#
#   Newspaper_y
# 0         NaN
# 1         NaN
# 2         NaN

# %%
#fill empty columns
df["Article_x"]= df["Article_x"].fillna("")
df["Article_y"]= df["Article_y"].fillna("") 
#create a unified text column
df["Article"] = df["Article_x"] + df["Article_y"]

#fill empty columns
df["Newspaper_x"]= df["Newspaper_x"].fillna("")
df["Newspaper_y"]= df["Newspaper_y"].fillna("") 
#create a unified text column
df["Newspaper"] = df["Newspaper_x"] + df["Newspaper_y"]

#inspect df
df.head(3)
# Out:
#    index  CID   AID  NO  CPA  BOV  BOA  NEU          Newspaper_x        Date  \
# 0      1    3   490   1    3    2    2    2     Aachener Zeitung  2020-05-15
# 1      2    3  3414   3    1    1    1    2  Stuttgarter Zeitung  2020-05-15
# 2      3    3  6996   4    3    2    2    1     Der Tagesspiegel  2020-05-10
#
#       Length                          Headline  \
# 0   43 words  FDP lädt ein zur Wahlversammlung
# 1  576 words        Wer stopft das Steuerloch?
# 2  801 words     Schulbetrieb und Klassenfahrt
#
#                                            Article_x         Author Article_y  \
# 0  Simmerath Der FDP Ortsverein Simmerath lädt zu...            NaN
# 1  Angesichts der gigantischen Steuer-ausfälle im...  Thorsten Knuf
# 2  "Kindeswohlgefährdung begünstigt. Experten bes...            NaN
#
#   Newspaper_y                                            Article  \
# 0              Simmerath Der FDP Ortsverein Simmerath lädt zu...
# 1              Angesichts der gigantischen Steuer-ausfälle im...
# 2              "Kindeswohlgefährdung begünstigt. Experten bes...
#
#              Newspaper
# 0     Aachener Zeitung
# 1  Stuttgarter Zeitung
# 2     Der Tagesspiegel

# %%
len(df)
# Out:
# 575

# %%
df["Article"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Remove duplicates

# %%
#remove duplicates
df.drop_duplicates(subset ="AID", keep = "first", inplace = True) 
len(df)
# Out:
# 497

# %%
#see if there is missing data
df = df[df["Article"].notna()]
len(df)
# Out:
# 497

# %% [markdown]
# ## Remove codes that don't align with the original data

# %%
df = df[df['Newspaper'] != ""]
len(df)
# Out:
# 487

# %% [markdown]
# ## Adapt column values

# %%
df["NEU"] = df["NEU"].replace(1, 0)  
df["NEU"] = df["NEU"].replace(2, 1)  #1 = yes
df["BOV"] = df["BOV"].replace(2, 0)  #1 = yes
df["BOA"] = df["BOA"].replace(2, 0)  #1 = yes
#inspect data
df.head(3)
# Out:
#    index  CID   AID  NO  CPA  BOV  BOA  NEU          Newspaper_x        Date  \
# 0      1    3   490   1    3    0    0    1     Aachener Zeitung  2020-05-15
# 1      2    3  3414   3    1    1    1    1  Stuttgarter Zeitung  2020-05-15
# 2      3    3  6996   4    3    0    0    0     Der Tagesspiegel  2020-05-10
#
#       Length                          Headline  \
# 0   43 words  FDP lädt ein zur Wahlversammlung
# 1  576 words        Wer stopft das Steuerloch?
# 2  801 words     Schulbetrieb und Klassenfahrt
#
#                                            Article_x         Author Article_y  \
# 0  Simmerath Der FDP Ortsverein Simmerath lädt zu...            NaN
# 1  Angesichts der gigantischen Steuer-ausfälle im...  Thorsten Knuf
# 2  "Kindeswohlgefährdung begünstigt. Experten bes...            NaN
#
#   Newspaper_y                                            Article  \
# 0              Simmerath Der FDP Ortsverein Simmerath lädt zu...
# 1              Angesichts der gigantischen Steuer-ausfälle im...
# 2              "Kindeswohlgefährdung begünstigt. Experten bes...
#
#              Newspaper
# 0     Aachener Zeitung
# 1  Stuttgarter Zeitung
# 2     Der Tagesspiegel

# %%
df
# Out:
#      index  CID   AID  NO  CPA  BOV  BOA  NEU  \
# 0        1    3   490   1    3    0    0    1
# 1        2    3  3414   3    1    1    1    1
# 2        3    3  6996   4    3    0    0    0
# 3        4    3  4894   5    3    0    0    0
# 4        5    3  3110   3    3    0    0    1
# 5        6    3  4674   5    1    0    0    1
# 6        7    3  2478   2    3    0    0    1
# 7        8    3  2264   2    6    0    0    0
# 8        9    3  5913   5    3    1    1    1
# 9       10    3  6483   4    4    1    1    1
# 10      11    3  7044   4    3    0    1    0
# 11      12    3  4441   5    5    0    0    0
# 12      13    3  5767   5    3    1    1    1
# 13      14    3  4961   5    3    0    0    0
# 14      15    3  6042   5    5    0    0    1
# 15      16    3  6698   4    5    0    0    0
# 16      17    3  5690   5    1    0    0    0
# 17      18    3   989   6    1    0    1    1
# 18      19    3  2115   2    3    0    0    1
# 19      20    3  6385   4    1    1    1    1
# 20      21    3  1876   2    1    1    0    0
# 21      22    3  1460   2    3    0    0    1
# 22      23    3   922   6    5    0    0    0
# 23      24    3  2964   2    3    1    1    1
# 24      25    3  1243   2    3    0    0    0
# 55      56    3   573   1    5    0    0    1
# 56      57    3  5591   5    1    1    1    0
# 57      58    3  5364   5    3    0    0    1
# 58      59    3   815   6    1    1    1    1
# 59      60    3  3401   3    5    1    0    1
# ..     ...  ...   ...  ..  ...  ...  ...  ...
# 545    548    1  4513   5    4    1    1    1
# 546    549    1  2691   2    1    0    0    1
# 547    550    1  3082   3    2    0    0    1
# 548    551    1  1014   6    5    0    0    0
# 549    552    1  2060   2    3    1    1    1
# 550    553    1  7092   4    6    0    0    0
# 551    554    1  6657   4    6    0    0    1
# 552    555    1  5553   5    3    0    0    0
# 553    556    1  6039   5    3    1    1    1
# 554    557    1  6237   5    6    0    0    0
# 555    558    1  2162   2    3    1    0    1
# 556    559    1   263   1    3    0    1    1
# 557    560    1  2976   2    3    1    0    1
# 558    561    1  6992   4    3    1    1    1
# 559    562    1  4327   5    5    0    0    1
# 560    563    1  5199   5    3    1    1    1
# 561    564    1  4105   5    3    0    0    1
# 562    565    1  3193   3    3    0    0    1
# 563    566    1  6350   4    1    0    0    0
# 564    567    1   276   1    6    0    0    1
# 565    568    1  5517   5    5    0    0    0
# 566    569    1  6225   5    1    1    0    1
# 567    570    1  1918   2    4    0    0    1
# 568    571    1  3236   3    3    0    0    1
# 569    572    1  3677   3    3    1    0    1
# 570    573    1  4010   5    6    0    0    0
# 571    574    1  2110   2    3    0    0    1
# 572    575    1   514   1    5    1    0    0
# 573    576    1    33   1    1    0    1    1
# 574    577    1  3931   5    1    1    1    0
#
#                                       Newspaper_x        Date      Length  \
# 0                                Aachener Zeitung  2020-05-15    43 words
# 1                             Stuttgarter Zeitung  2020-05-15   576 words
# 2                                Der Tagesspiegel  2020-05-10   801 words
# 3    Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-12   315 words
# 4                             Stuttgarter Zeitung  2020-04-30   287 words
# 5    Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-22    84 words
# 6                                 Rheinische Post  2020-05-07    85 words
# 7                                 Rheinische Post  2020-05-14   152 words
# 8    Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-06   391 words
# 9                                Der Tagesspiegel  2020-04-30   673 words
# 10                               Der Tagesspiegel  2020-05-06   777 words
# 11   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-21   568 words
# 12   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-09   308 words
# 13   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-15   477 words
# 14   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-09   108 words
# 15                               Der Tagesspiegel  2020-05-18   398 words
# 16   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-08   577 words
# 17                                       Die Welt  2020-05-04   505 words
# 18                                Rheinische Post  2020-05-15   554 words
# 19                               Der Tagesspiegel  2020-04-30   683 words
# 20                                Rheinische Post  2020-05-05   399 words
# 21                                Rheinische Post  2020-04-21   705 words
# 22                                       Die Welt  2020-05-16  1117 words
# 23                                Rheinische Post  2020-05-19   315 words
# 24                                Rheinische Post  2020-04-25   419 words
# 55                               Aachener Zeitung  2020-05-02    92 words
# 56   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-02   734 words
# 57   Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-12   390 words
# 58                                       Die Welt  2020-04-20  1255 words
# 59                            Stuttgarter Zeitung  2020-05-07  1084 words
# ..                                            ...         ...         ...
# 545  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-29   507 words
# 546                               Rheinische Post  2020-05-07   109 words
# 547                           Stuttgarter Zeitung  2020-04-29   499 words
# 548                                      Die Welt  2020-05-18   839 words
# 549                               Rheinische Post  2020-05-14   629 words
# 550                              Der Tagesspiegel  2020-05-11  1227 words
# 551                              Der Tagesspiegel  2020-04-21   260 words
# 552  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-05  1095 words
# 553  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-04   441 words
# 554  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-02   619 words
# 555                               Rheinische Post  2020-05-14  1187 words
# 556                              Aachener Zeitung  2020-05-07   531 words
# 557                               Rheinische Post  2020-05-14   334 words
# 558                              Der Tagesspiegel  2020-05-07  1050 words
# 559  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-29   528 words
# 560  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-14   966 words
# 561  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-27   264 words
# 562                           Stuttgarter Zeitung  2020-04-29   339 words
# 563                              Der Tagesspiegel  2020-04-27   769 words
# 564                              Aachener Zeitung  2020-05-19   726 words
# 565  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-11  1116 words
# 566  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-05-02   277 words
# 567                               Rheinische Post  2020-05-04   455 words
# 568                           Stuttgarter Zeitung  2020-04-30   834 words
# 569                           Stuttgarter Zeitung  2020-05-15   383 words
# 570  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-22   953 words
# 571                               Rheinische Post  2020-05-15   788 words
# 572                              Aachener Zeitung  2020-05-14   205 words
# 573                              Aachener Zeitung  2020-04-20   480 words
# 574  Süddeutsche Zeitung (inkl. Regionalausgaben)  2020-04-25  1215 words
#
#                                               Headline  \
# 0                     FDP lädt ein zur Wahlversammlung
# 1                           Wer stopft das Steuerloch?
# 2                        Schulbetrieb und Klassenfahrt
# 3                CSU UND AFD; Rote Linie überschritten
# 4                           Anklage im Mordfall Lübcke
# 5      Entscheidung über neue Militär-Jets erst später
# 6            Alexander Schumacher hält Sprechstunde ab
# 7                             Zu wichtig für Wahlkampf
# 8    Im Nachhinein solide; Im umstrittenen Haushalt...
# 9    Note: Mangelhaft Der Landeselternausschuss kri...
# 10   Angst um die Bürgerdaten Ohne Digitalisierung ...
# 11                        BREXIT; Stur Richtung Klippe
# 12               Herrmann hält an Grenzkontrollen fest
# 13   Männerwirtschaft; Thomas Mayer und Robert Hube...
# 14                            Das Wort; Das Wort mit A
# 15   Obama im US-Wahlkampf Das andere Amerika Von M...
# 16                    EUROPA; Die Öffnung ist zwingend
# 17   "Es geht hier um die Grundwerte unseres Gemein...
# 18   Polizeidurchsuchung  im Haaner Rathaus; Neue E...
# 19   Spielen wagen Die Politik scheint überzeugt vo...
# 20          SPD streitet über Högl als Wehrbeauftragte
# 21   Tönisvorst bekommt Waldkindergarten; Zum neuen...
# 22   Gehorchen oder aufbegehren?; Querulanten, Enga...
# 23   Initiative droht mit Aus für Köntges; Sozialau...
# 24    Notizen aus dem Krefelder Corona-Tagebuch; No...
# 55          Volksentscheid über Cannabis-Legalisierung
# 56   Die Kontrolle über den Text; Der BGH fällt zwe...
# 57   Es gibt nix Feiners wia a Schweiners!; Bayernp...
# 58   "Mit künstlicher Beatmung wird viel Geld gemac...
# 59          Eine Friseurin wird zur Freiheitskämpferin
# ..                                                 ...
# 545  Aslyunterkunft unter Quarantäne; Sicherheitsdi...
# 546  Bundesregierung: Balearen-Urlaub nicht abschr...
# 547         Sind Unis digital zu schlecht aufgestellt?
# 548  Europas Superkampfjet soll kein Killerroboter ...
# 549  Statt Hygiene-Demo nur Kundgebung; In Dinsla...
# 550  Von Aids für Corona lernen Die Krise in den 19...
# 551  Bundesbank: Die Rezession wird schwer Berater:...
# 552  Der Zielstrebige; Der neue Neubiberger Bürgerm...
# 553  Zwei Millionen für die Gemeinde; Altomünster w...
# 59   Wenn wir ans Telefon gehen, haben wir auch geö...
# ..                                                 ...
# 545  Erding - Die Forsterner Grünen kritisieren in ...
# 546  Berlin (dpa) Urlauber können im Sommer unter U...
# 547  Die Universitäten stehen vor einem sehr schwie...
# 548  Wie sehen in 20, 30, 40 oder 50 Jahren Krieg u...
# 549  Dinslaken (aha)Tausende haben in den vergangen...
# 550  Die Coronakrise sei die schlimmste Pandemie se...
# 551  Frankfurt am Main/Brüssel - Die deutsche Wirts...
# 552  Neubiberg - Zum Treffen im Zukunftswald im Lan...
# 553  Altomünster - Die Marktgemeinde wird im Sommer...
# 554  ,,Eigentlich mache ich momentan eine Ausbildun...
# 555  marlen Kess Düsseldorf Seit sieben Wochen sind...
# 556  Von Guido Jansen   Jülich Der Brainergy-Park h...
# 557  Düsseldorf (dpa) In Deutschland gibt es derzei...
# 558  B erlin reiht sich nicht ein in die Riege der ...
# 559  Wien - Die erste Öffnung hat keinen Rückschlag...
# 560  München - Haushaltskonsolidierung, Gesundheits...
# 561  Dachau - Die Fraktion der Überparteilichen Bür...
# 562  Genau beziffern kann Finanzministerin Edith Si...
# 563  Berlin - Der Petersberger Klimadialog soll all...
# 564  Freiburg Ein Wissenschaftlerteam der Universit...
# 565  Unser Kontinent steht inmitten einer Bewährung...
# 566  Landkreis - Wegen der Corona-Krise ist auch im...
# 567  Rheurdt (got) Im Nachhinein ist Robert Peerenb...
# 568  Normalerweise würden Felix Winkler und seine K...
# 569  Der Betriebsausschuss Städtische Gebäude hat z...
# 570  Seit er als verschreckter Schüler einer Kadett...
# 571  Peter Clement Haan/Kreis Mettmann In dieser St...
# 572  Eine entspannte Urlaubsreise sieht sicher ande...
# 573  Berlin Entwicklungsminister Gerd Müller plädie...
# 574  Berlin/München - Knapp 250 Menschen sind in So...
#
#                            Author Article_y Newspaper_y  \
# 0                             NaN
# 1                   Thorsten Knuf
# 2                             NaN
# 3            VON MARTIN MÜHLFENZL
# 4                             AFP
# 5                             MSZ
# 6                             NaN
# 7                  Gruhn, Andreas
# 8                             KBH
# 9               Ronja Ringelstein
# 10                  Robert Kiesel
# 11                VON BJÖRN FINKE
# 12                           NELL
# 13                  BERNHARD LOHR
# 14                            NaN
# 15                            NaN
# 16             VON JENS SCHNEIDER
# 17                            NaN
# 18                 Clement, Peter
# 19                            NaN
# 20                    Drebes, Jan
# 21           Wickerath, Stephanie
# 22                   Alan Posener
# 23                 Gruhn, Andreas
# 24                     Voss, Jens
# 55                            NaN
# 56               WOLFGANG JANISCH
# 57                            WKB
# 58                    Kaja Klapsa
# 59                 Frank Herrmann
# ..                            ...       ...         ...
# 545                      FLO, TDR
# 546                           NaN
# 547                Norbert Wallet
# 548               Gerhard Hegmann
# 549                           NaN
# 550                   Dirk Ludigs
# 551                           NaN
# 552              VON DANIELA BODE
# 553                          KRAM
# 554         PROTOKOLL: NINA BÜCHS
# 555                   Keß, Marlen
# 556                           NaN
# 557                           NaN
# 558                Sabine Beikler
# 557  Düsseldorf (dpa) In Deutschland gibt es derzei...
# 558  B erlin reiht sich nicht ein in die Riege der ...
# 559  Wien - Die erste Öffnung hat keinen Rückschlag...
# 560  München - Haushaltskonsolidierung, Gesundheits...
# 561  Dachau - Die Fraktion der Überparteilichen Bür...
# 562  Genau beziffern kann Finanzministerin Edith Si...
# 563  Berlin - Der Petersberger Klimadialog soll all...
# 564  Freiburg Ein Wissenschaftlerteam der Universit...
# 565  Unser Kontinent steht inmitten einer Bewährung...
# 566  Landkreis - Wegen der Corona-Krise ist auch im...
# 567  Rheurdt (got) Im Nachhinein ist Robert Peerenb...
# 568  Normalerweise würden Felix Winkler und seine K...
# 569  Der Betriebsausschuss Städtische Gebäude hat z...
# 570  Seit er als verschreckter Schüler einer Kadett...
# 571  Peter Clement Haan/Kreis Mettmann In dieser St...
# 572  Eine entspannte Urlaubsreise sieht sicher ande...
# 573  Berlin Entwicklungsminister Gerd Müller plädie...
# 574  Berlin/München - Knapp 250 Menschen sind in So...
#
#                                         Newspaper
# 0                                Aachener Zeitung
# 1                             Stuttgarter Zeitung
# 2                                Der Tagesspiegel
# 3    Süddeutsche Zeitung (inkl. Regionalausgaben)
# 4                             Stuttgarter Zeitung
# 5    Süddeutsche Zeitung (inkl. Regionalausgaben)
# 6                                 Rheinische Post
# 7                                 Rheinische Post
# 8    Süddeutsche Zeitung (inkl. Regionalausgaben)
# 9                                Der Tagesspiegel
# 10                               Der Tagesspiegel
# 11   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 12   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 13   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 14   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 15                               Der Tagesspiegel
# 16   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 17                                       Die Welt
# 18                                Rheinische Post
# 19                               Der Tagesspiegel
# 20                                Rheinische Post
# 21                                Rheinische Post
# 22                                       Die Welt
# 23                                Rheinische Post
# 24                                Rheinische Post
# 55                               Aachener Zeitung
# 56   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 57   Süddeutsche Zeitung (inkl. Regionalausgaben)
# 58                                       Die Welt
# 59                            Stuttgarter Zeitung
# ..                                            ...
# 545  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 546                               Rheinische Post
# 547                           Stuttgarter Zeitung
# 548                                      Die Welt
# 549                               Rheinische Post
# 550                              Der Tagesspiegel
# 551                              Der Tagesspiegel
# 552  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 553  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 554  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 555                               Rheinische Post
# 556                              Aachener Zeitung
# 557                               Rheinische Post
# 558                              Der Tagesspiegel
# 559  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 560  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 561  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 562                           Stuttgarter Zeitung
# 563                              Der Tagesspiegel
# 564                              Aachener Zeitung
# 565  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 566  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 567                               Rheinische Post
# 568                           Stuttgarter Zeitung
# 569                           Stuttgarter Zeitung
# 570  Süddeutsche Zeitung (inkl. Regionalausgaben)
# 571                               Rheinische Post
# 572                              Aachener Zeitung
# 573                              Aachener Zeitung
# 574  Süddeutsche Zeitung (inkl. Regionalausgaben)
#
# [487 rows x 18 columns]

# %% [markdown]
# ## Inspect data

# %%
#initial overview over the number of articles per newspaper
df.groupby("Newspaper").describe()
# Out:
#                                               index                          \
#                                               count        mean         std
# Newspaper
# Aachener Zeitung                               31.0  338.903226  173.931855
# Der Tagesspiegel                               42.0  310.071429  187.818593
# Die Welt                                       28.0  259.714286  167.226805
# Rheinische Post                                77.0  283.896104  175.240480
# Stuttgarter Zeitung                            40.0  297.950000  184.687671
# Süddeutsche Zeitung (inkl. Regionalausgaben)  123.0  299.569106  181.074212
# aachener zeitung (www)                         20.0  349.900000  102.930687
# der tagesspiegel (www)                         39.0  376.743590  104.337438
# die welt (www)                                 25.0  374.080000  109.067609
# rheinische post (www)                          22.0  343.181818  103.791750
# stuttgarter zeitung (www)                      21.0  329.619048  117.793665
# sueddeutschet politik (www)                    19.0  329.473684  116.963607
#
#                                                                             \
#                                                 min     25%    50%     75%
# Newspaper
# Aachener Zeitung                                1.0  202.00  325.0  513.50
# Der Tagesspiegel                                3.0  136.75  343.0  493.25
# Die Welt                                       18.0  126.75  238.5  364.25
# Rheinische Post                                 7.0  133.00  295.0  374.00
# Stuttgarter Zeitung                             2.0  124.75  311.0  496.75
# Süddeutsche Zeitung (inkl. Regionalausgaben)    4.0  114.50  313.0  489.00
# aachener zeitung (www)                        182.0  216.75  387.5  415.00
# der tagesspiegel (www)                        183.0  304.50  410.0  456.50
# die welt (www)                                184.0  226.00  423.0  456.00
# rheinische post (www)                         198.0  218.00  390.0  428.00
# stuttgarter zeitung (www)                     185.0  214.00  404.0  439.00
# sueddeutschet politik (www)                   187.0  197.50  386.0  429.50
#
#                                                        CID            ...  \
#                                                 max  count      mean  ...
# Newspaper                                                             ...
# Aachener Zeitung                              576.0   31.0  2.451613  ...
# Der Tagesspiegel                              566.0   42.0  2.690476  ...
# Die Welt                                      551.0   28.0  2.642857  ...
# Rheinische Post                               574.0   77.0  2.389610  ...
# Stuttgarter Zeitung                           572.0   40.0  2.650000  ...
# Süddeutsche Zeitung (inkl. Regionalausgaben)  577.0  123.0  2.536585  ...
# aachener zeitung (www)                        476.0   20.0  1.600000  ...
# der tagesspiegel (www)                        479.0   39.0  1.410256  ...
# die welt (www)                                477.0   25.0  1.400000  ...
# rheinische post (www)                         454.0   22.0  1.636364  ...
# stuttgarter zeitung (www)                     475.0   21.0  1.333333  ...
# sueddeutschet politik (www)                   478.0   19.0  1.368421  ...
#
#                                               BOA         NEU            \
#                                               75%  max  count      mean
# Newspaper
# Aachener Zeitung                              1.0  1.0   31.0  0.741935
# Der Tagesspiegel                              1.0  1.0   42.0  0.619048
# Die Welt                                      1.0  1.0   28.0  0.392857
# Rheinische Post                               1.0  1.0   77.0  0.701299
# Stuttgarter Zeitung                           1.0  1.0   40.0  0.725000
# Süddeutsche Zeitung (inkl. Regionalausgaben)  1.0  1.0  123.0  0.560976
# aachener zeitung (www)                        1.0  1.0   20.0  0.650000
# der tagesspiegel (www)                        0.0  1.0   39.0  0.384615
# die welt (www)                                1.0  1.0   25.0  0.480000
# rheinische post (www)                         1.0  1.0   22.0  0.500000
# stuttgarter zeitung (www)                     0.0  1.0   21.0  0.714286
# sueddeutschet politik (www)                   1.0  1.0   19.0  0.263158
#
#                                                                             \
#                                                    std  min  25%  50%  75%
# Newspaper
# Aachener Zeitung                              0.444803  0.0  0.5  1.0  1.0
# Der Tagesspiegel                              0.491507  0.0  0.0  1.0  1.0
# Die Welt                                      0.497347  0.0  0.0  0.0  1.0
# Rheinische Post                               0.460690  0.0  0.0  1.0  1.0
# Stuttgarter Zeitung                           0.452203  0.0  0.0  1.0  1.0
# Süddeutsche Zeitung (inkl. Regionalausgaben)  0.498298  0.0  0.0  1.0  1.0
# aachener zeitung (www)                        0.489360  0.0  0.0  1.0  1.0
# der tagesspiegel (www)                        0.492864  0.0  0.0  0.0  1.0
# die welt (www)                                0.509902  0.0  0.0  0.0  1.0
# rheinische post (www)                         0.511766  0.0  0.0  0.5  1.0
# stuttgarter zeitung (www)                     0.462910  0.0  0.0  1.0  1.0
# sueddeutschet politik (www)                   0.452414  0.0  0.0  0.0  0.5
#
#
#                                               max
# Newspaper
# Aachener Zeitung                              1.0
# Der Tagesspiegel                              1.0
# Die Welt                                      1.0
# Rheinische Post                               1.0
# Stuttgarter Zeitung                           1.0
# Süddeutsche Zeitung (inkl. Regionalausgaben)  1.0
# aachener zeitung (www)                        1.0
# der tagesspiegel (www)                        1.0
# die welt (www)                                1.0
# rheinische post (www)                         1.0
# stuttgarter zeitung (www)                     1.0
# sueddeutschet politik (www)                   1.0
#
# [12 rows x 64 columns]

# %%
#label distribution per newspaper

dw = df[df['Newspaper'].isin(["Die Welt", "die welt (www)"])]
print("Die Welt")
print("Balance of actors")
print(dw["BOA"].value_counts())
print("Balance of viewpoints")
print(dw["BOV"].value_counts())
print("Neutrality")
print(dw["NEU"].value_counts())

print("")

sz = df[df['Newspaper'].isin(["Süddeutsche Zeitung (inkl. Regionalausgaben)", "sueddeutschet politik (www)"])]
print("Die Süddeutsche:")
print("Balance of actors")
print(sz["BOA"].value_counts())
print("Balance of viewpoints")
print(sz["BOV"].value_counts())
print("Neutrality")
print(sz["NEU"].value_counts())

print("")

ts = df[df['Newspaper'].isin(["Der Tagesspiegel", "der tagesspiegel (www)"])]   
print("Der Tagesspiegel")
print("Balance of actors")
print(ts["BOA"].value_counts())
print("Balance of viewpoints")
print(ts["BOV"].value_counts())
print("Neutrality")
print(ts["NEU"].value_counts())

print("")

az = df[df['Newspaper'].isin(["Aachener Zeitung", "aachener zeitung (www)"])]
print("Aachener Zeitung")
print("Balance of actors")
print(az["BOA"].value_counts())
print("Balance of viewpoints")
print(az["BOV"].value_counts())
print("Neutrality")
print(az["NEU"].value_counts())

print("")

rp = df[df['Newspaper'].isin(["Rheinische Post", "rheinische post (www)"])]
print("Rheinische Post")
print("Balance of actors")
print(rp["BOA"].value_counts())
print("Balance of viewpoints")
print(rp["BOV"].value_counts())
print("Neutrality")
print(rp["NEU"].value_counts())

print("")

stz = df[df['Newspaper'].isin(["Stuttgarter Zeitung", "stuttgarter zeitung (www)"])]
print("Stuttgarter Zeitung")
print("Balance of actors")
print(stz["BOA"].value_counts())
print("Balance of viewpoints")
print(stz["BOV"].value_counts())
print("Neutrality")
print(stz["NEU"].value_counts())
# Out:
# Die Welt
# Balance of actors
# 0    28
# 1    25
# Name: BOA, dtype: int64
# Balance of viewpoints
# 1    29
# 0    24
# Name: BOV, dtype: int64
# Neutrality
# 0    30
# 1    23
# Name: NEU, dtype: int64
#
# Die Süddeutsche:
# Balance of actors
# 0    93
# 1    49
# Name: BOA, dtype: int64
# Balance of viewpoints
# 0    73
# 1    69
# Name: BOV, dtype: int64
# Neutrality
# 1    74
# 0    68
# Name: NEU, dtype: int64
#
# Der Tagesspiegel
# Balance of actors
# 0    57
# 1    24
# Name: BOA, dtype: int64
# Balance of viewpoints
# 1    41
# 0    40
# Name: BOV, dtype: int64
# Neutrality
# 1    41
# 0    40
# Name: NEU, dtype: int64
#
# Aachener Zeitung
# Balance of actors
# 0    31
# 1    20
# Name: BOA, dtype: int64
# Balance of viewpoints
# 0    35
# 1    16
# Name: BOV, dtype: int64
# Neutrality
# 1    36
# 0    15
# Name: NEU, dtype: int64
#
# Rheinische Post
# Balance of actors
# 0    65
# 1    34
# Name: BOA, dtype: int64
# Balance of viewpoints
# 0    54
# 1    45
# Name: BOV, dtype: int64
# Neutrality
# 1    65
# 0    34
# Name: NEU, dtype: int64
#
# Stuttgarter Zeitung
# Balance of actors
# 0    46
# 1    15
# Name: BOA, dtype: int64
# Balance of viewpoints
# 0    37
# 1    24
# Name: BOV, dtype: int64
# Neutrality
# 1    44
# 0    17
# Name: NEU, dtype: int64

# %%
#overall distribution of labels
print("Balance of actors")
print(df["BOA"].value_counts())
print("")
print("Balance of vviews")
print(df["BOV"].value_counts())
print("")
print("Neutrality")
print(df["NEU"].value_counts())
# Out:
# Balance of actors
# 0    320
# 1    167
# Name: BOA, dtype: int64
#
# Balance of vviews
# 0    263
# 1    224
# Name: BOV, dtype: int64
#
# Neutrality
# 1    283
# 0    204
# Name: NEU, dtype: int64

# %%
#overview of articles per coder
df["CID"].value_counts()
# Out:
# 2    166
# 3    155
# 1    128
# 4     38
# Name: CID, dtype: int64

# %% [markdown]
# ## Saving the datafile

# %%
df.to_excel("mca_finaldata.xlsx")
